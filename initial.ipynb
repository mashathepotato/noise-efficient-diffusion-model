# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Colab Notebooks/Efficient_Diffusion/
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Colab Notebooks/Efficient_Diffusion'
# /content/drive/MyDrive/Colab Notebooks

# %%
# %cd noise-efficient-diffusion-model/
# Out:
# /content/drive/MyDrive/Colab Notebooks/Efficient_Diffusion/noise-efficient-diffusion-model

# %%
# !git config --global user.email "realcowcitizen@gmail.com"
# !git config --global user.name "Masha Baidachna"

# %%
# !git remote set-url origin https://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@github.com/mashathepotato/noise-efficient-diffusion-model.git

# %%
# !git push -u origin main
# Out:
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 1.48 KiB | 152.00 KiB/s, done.
# Total 4 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), done.
# To https://github.com/mashathepotato/noise-efficient-diffusion-model.git
#    296498a..6705c90  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
